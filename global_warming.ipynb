# %%
pip install pandas
# Out:
# WARNING: The directory '/Users/atewari/Library/Caches/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 1.3 MB/s eta 0:00:0000:0100:01m
# ...
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /usr/local/Cellar/jupyterlab/4.2.5_1/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.read_csv("global_warming_dataset.csv")
# Out:
#           Country  Year  Temperature_Anomaly  CO2_Emissions    Population  \
# 0      Country_93  2014             0.444954   4.579080e+08  4.926732e+08
# 1      Country_15  2020            -1.171616   5.049503e+08  1.252169e+09
# 2      Country_88  2014             0.560926   8.174279e+08  8.715338e+08
# 3     Country_161  2018            -1.776189   7.225106e+08  1.153826e+09
# 4      Country_58  2019             0.655015   5.151287e+08  8.878241e+08
# ...           ...   ...                  ...            ...           ...
# 8745  Country_191  2022            -1.493139   6.243718e+08  1.238373e+09
# 8746   Country_20  2021            -1.785858   6.532305e+08  1.049440e+09
# 8747  Country_158  2013             1.488299   2.076319e+08  4.279195e+08
# 8748  Country_107  2014            -1.776688   6.128349e+08  8.019814e+08
# 8749   Country_69  2018            -1.400119   8.156151e+08  1.476783e+09
#
#       Forest_Area           GDP  Renewable_Energy_Usage  Methane_Emissions  \
# ...

# %%
df = pd.read_csv("global_warming_dataset.csv")

# %%
year_filter = df['Year'] >= 2020

# %%
df1 = df[year_filter]

# %%
columns = ['Country', 'Year', 'CO2_Emissions', 'Population', 'Forest_Area', 'GDP', 'Renewable_Energy_Usage', 'Sea_Level_Rise', 'Per_Capita_Emissions', 'Fossil_Fuel_Usage']

# %%
df1[columns].to_csv('data.csv', index=False)

# %%
df1_desc = df1[columns].describe()

# %%
df1_desc
# Out:
#               Year  CO2_Emissions    Population  Forest_Area           GDP  \
# count  3106.000000   3.106000e+03  3.106000e+03  3106.000000  3.106000e+03
# mean   2021.478107   5.003586e+08  7.463359e+08    51.432038  4.986892e+12
# std       1.110775   2.845867e+08  4.338750e+08    28.505584  2.882581e+12
# min    2020.000000   7.107863e+05  1.280287e+06     0.035802  1.524737e+08
# 25%    2020.250000   2.597854e+08  3.662079e+08    27.206298  2.491796e+12
# 50%    2021.000000   4.986744e+08  7.395169e+08    52.395491  4.920039e+12
# 75%    2022.000000   7.443226e+08  1.116762e+09    75.659880  7.456137e+12
# max    2023.000000   9.998894e+08  1.499200e+09    99.914539  9.993365e+12
#
#        Renewable_Energy_Usage  Sea_Level_Rise  Per_Capita_Emissions  \
# count             3106.000000     3106.000000           3106.000000
# mean                51.050592       22.779280             10.125480
# std                 28.656418       15.775171              5.783194
# ...

# %%
df1_desc.to_csv('global_warming_dataset_desc.csv', index=False)
